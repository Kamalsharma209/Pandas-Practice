# %% [markdown]
# <a href="https://colab.research.google.com/github/Kamalsharma209/Pandas-Practice/blob/main/_Loc_and_ILoc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('Students.csv')

# %%
df
# Out:
#    StudentID          Name  Age  Gender Department  Year  CGPA  Attendance  \
# 0      CS001  Arjun Sharma   19    Male     CSAIML     2   8.5        85.5
# 1      CS002   Priya Patel   20  Female     CSAIML     2   7.8        90.2
# 2      CS003   Rahul Verma   21    Male     CSAIML     2   6.9         NaN
# 3      CS004  Ananya Gupta   19  Female     CSAIML     2   9.1        92.0
# 4      CS005  Vikram Singh   20    Male     CSAIML     2   7.5        78.5
# ..       ...           ...  ...     ...        ...   ...   ...         ...
# 95     CS096   Swara Reddy   21  Female     CSAIML     2   8.9        92.0
# 96     CS097    Ayan Singh   19    Male     CSAIML     2   7.4        78.5
# 97     CS098    Riya Joshi   20  Female     CSAIML     2   8.7        90.5
# 98     CS099    Shivam Rao   21    Male     CSAIML     2   7.8        81.0
# 99     CS100     Avni Nair   19  Female     CSAIML     2   9.0        93.0
#
# ...

# %%
df.loc[0:3,['Name','Age']]
# Out:
#            Name  Age
# 0  Arjun Sharma   19
# 1   Priya Patel   20
# 2   Rahul Verma   21
# 3  Ananya Gupta   19

# %%
df.iloc[0:3,1:4]
# Out:
#            Name  Age  Gender
# 0  Arjun Sharma   19    Male
# 1   Priya Patel   20  Female
# 2   Rahul Verma   21    Male

# %%
data = {
    'Name': ['Amit','Sumit','Ram'],
    'Age' : [29,30,31]
}

# %%
import pandas as pd
df1 = pd.DataFrame(data, index =['a','b','c'])
df1
# Out:
#     Name  Age
# a   Amit   29
# b  Sumit   30
# c    Ram   31

# %%
df1.loc['a':'c',['Name','Age']]
# Out:
#     Name  Age
# a   Amit   29
# b  Sumit   30
# c    Ram   31

# %%
df1
# Out:
#     Name  Age
# a   Amit   29
# b  Sumit   30
# c    Ram   31

# %%
df1.iloc[0:2,0:2]
# Out:
#     Name  Age
# a   Amit   29
# b  Sumit   30

# %%
df1
# Out:
#     Name  Age
# a   Amit   29
# b  Sumit   30
# c    Ram   31

# %%
Temp = df1['Age']>39

# %%
Temp
# Out:
# a    False
# b    False
# c    False
# Name: Age, dtype: bool

# %%
df1[Temp]
# Out:
# Empty DataFrame
# Columns: [Name, Age]
# Index: []

# %%
df1[df1['Age']>29]
# Out:
#     Name  Age
# b  Sumit   30
# c    Ram   31

# %%
op = df['CGPA'] > 6
# Out:
#    StudentID          Name  Age  Gender Department  Year  CGPA  Attendance  \
# 0      CS001  Arjun Sharma   19    Male     CSAIML     2   8.5        85.5
# 1      CS002   Priya Patel   20  Female     CSAIML     2   7.8        90.2
# 2      CS003   Rahul Verma   21    Male     CSAIML     2   6.9         NaN
# 3      CS004  Ananya Gupta   19  Female     CSAIML     2   9.1        92.0
# 4      CS005  Vikram Singh   20    Male     CSAIML     2   7.5        78.5
# ..       ...           ...  ...     ...        ...   ...   ...         ...
# 95     CS096   Swara Reddy   21  Female     CSAIML     2   8.9        92.0
# 96     CS097    Ayan Singh   19    Male     CSAIML     2   7.4        78.5
# 97     CS098    Riya Joshi   20  Female     CSAIML     2   8.7        90.5
# 98     CS099    Shivam Rao   21    Male     CSAIML     2   7.8        81.0
# 99     CS100     Avni Nair   19  Female     CSAIML     2   9.0        93.0
#
# ...

# %%
lol = (df['CGPA'] > 6) & (df['Age'] > 20) & (df['City'] == 'Delhi') & (df['Gender'] == 'Male')
df[lol]
# Out:
#    StudentID           Name  Age Gender Department  Year  CGPA  Attendance  \
# 2      CS003    Rahul Verma   21   Male     CSAIML     2   6.9         NaN
# 32     CS033   Vivek Sharma   21   Male     CSAIML     2   7.2        77.0
# 62     CS063    Ravi Sharma   21   Male     CSAIML     2   7.3        79.0
# 92     CS093  Raghav Sharma   21   Male     CSAIML     2   7.3        79.0
#
#    Internship   Club  ...                    Email  Favorite_Subject  \
# 2         Yes     AI  ...    rahul.verma@email.com  Machine Learning
# 32        Yes  Music  ...   vivek.sharma@email.com        Statistics
# 62        Yes  Music  ...    ravi.sharma@email.com        Statistics
# 92        Yes  Music  ...  raghav.sharma@email.com        Statistics
#
#     Library_Visits  GPA_Trend   City  Social_Media_Usage_Hrs Part_Time_Job  \
# 2                8       Down  Delhi                     4.0           Yes
# 32               6       Down  Delhi                     4.3           Yes
# ...

# %% [markdown]
# <a href="https://colab.research.google.com/github/Kamalsharma209/Pandas-Practice/blob/main/Read_operation_in_CSV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Read operation in CSV file**

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Students.csv")
df
# Out:
#    StudentID          Name  Age  Gender Department  Year  CGPA  Attendance  \
# 0      CS001  Arjun Sharma   19    Male     CSAIML     2   8.5        85.5
# 1      CS002   Priya Patel   20  Female     CSAIML     2   7.8        90.2
# 2      CS003   Rahul Verma   21    Male     CSAIML     2   6.9         NaN
# 3      CS004  Ananya Gupta   19  Female     CSAIML     2   9.1        92.0
# 4      CS005  Vikram Singh   20    Male     CSAIML     2   7.5        78.5
# ..       ...           ...  ...     ...        ...   ...   ...         ...
# 95     CS096   Swara Reddy   21  Female     CSAIML     2   8.9        92.0
# 96     CS097    Ayan Singh   19    Male     CSAIML     2   7.4        78.5
# 97     CS098    Riya Joshi   20  Female     CSAIML     2   8.7        90.5
# 98     CS099    Shivam Rao   21    Male     CSAIML     2   7.8        81.0
# 99     CS100     Avni Nair   19  Female     CSAIML     2   9.0        93.0
#
# ...

# %%
df2 = pd.read_csv("Students.csv", nrows=1)
df2
# Out:
#   StudentID          Name  Age Gender Department  Year  CGPA  Attendance  \
# 0     CS001  Arjun Sharma   19   Male     CSAIML     2   8.5        85.5
#
#   Internship      Club  ...                   Email  Favorite_Subject  \
# 0        Yes  Robotics  ...  arjun.sharma@email.com                AI
#
#    Library_Visits  GPA_Trend       City  Social_Media_Usage_Hrs Part_Time_Job  \
# 0              10         Up  Bangalore                     2.5           Yes
#
#   Project_Grade   Feedback Placement_Eligible
# 0             A  Excellent               True
#
# [1 rows x 26 columns]

# %%
df3 = pd.read_csv("Students.csv",usecols=["Gender"])
df3
# Out:
#     Gender
# 0     Male
# 1   Female
# 2     Male
# 3   Female
# 4     Male
# ..     ...
# 95  Female
# 96    Male
# 97  Female
# 98    Male
# 99  Female
#
# [100 rows x 1 columns]

# %%
df4 = pd.read_csv("Students.csv",usecols=["Year","CGPA"])
df4
# Out:
#     Year  CGPA
# 0      2   8.5
# 1      2   7.8
# 2      2   6.9
# 3      2   9.1
# 4      2   7.5
# ..   ...   ...
# 95     2   8.9
# 96     2   7.4
# 97     2   8.7
# 98     2   7.8
# 99     2   9.0
#
# [100 rows x 2 columns]

# %%
df5 = pd.read_csv("Students.csv",usecols=[0,3])
df5
# Out:
#    StudentID  Gender
# 0      CS001    Male
# 1      CS002  Female
# 2      CS003    Male
# 3      CS004  Female
# 4      CS005    Male
# ..       ...     ...
# 95     CS096  Female
# 96     CS097    Male
# 97     CS098  Female
# 98     CS099    Male
# 99     CS100  Female
#
# [100 rows x 2 columns]

# %%
df6 = pd.read_csv("Students.csv",skiprows=[0])
df6
# Out:
#     CS001  Arjun Sharma  19    Male  CSAIML  2  8.5  85.5  Yes  Robotics  ...  \
# 0   CS002   Priya Patel  20  Female  CSAIML  2  7.8  90.2   No  Literary  ...
# 1   CS003   Rahul Verma  21    Male  CSAIML  2  6.9   NaN  Yes        AI  ...
# 2   CS004  Ananya Gupta  19  Female  CSAIML  2  9.1  92.0   No    Coding  ...
# 3   CS005  Vikram Singh  20    Male  CSAIML  2  7.5  78.5  Yes       NaN  ...
# 4   CS006    Neha Reddy  22  Female  CSAIML  2  NaN  88.0   No    Debate  ...
# ..    ...           ...  ..     ...     ... ..  ...   ...  ...       ...  ...
# 94  CS096   Swara Reddy  21  Female  CSAIML  2  8.9  92.0   No  Literary  ...
# 95  CS097    Ayan Singh  19    Male  CSAIML  2  7.4  78.5  Yes  Robotics  ...
# 96  CS098    Riya Joshi  20  Female  CSAIML  2  8.7  90.5   No    Debate  ...
# 97  CS099    Shivam Rao  21    Male  CSAIML  2  7.8  81.0  Yes     Music  ...
# 98  CS100     Avni Nair  19  Female  CSAIML  2  9.0  93.0   No        AI  ...
#
# ...

# %%
df7 = pd.read_csv("Students.csv",index_col="Gender")
df7
# Out:
#        StudentID          Name  Age Department  Year  CGPA  Attendance  \
# Gender
# Male       CS001  Arjun Sharma   19     CSAIML     2   8.5        85.5
# Female     CS002   Priya Patel   20     CSAIML     2   7.8        90.2
# Male       CS003   Rahul Verma   21     CSAIML     2   6.9         NaN
# Female     CS004  Ananya Gupta   19     CSAIML     2   9.1        92.0
# Male       CS005  Vikram Singh   20     CSAIML     2   7.5        78.5
# ...          ...           ...  ...        ...   ...   ...         ...
# Female     CS096   Swara Reddy   21     CSAIML     2   8.9        92.0
# Male       CS097    Ayan Singh   19     CSAIML     2   7.4        78.5
# Female     CS098    Riya Joshi   20     CSAIML     2   8.7        90.5
# Male       CS099    Shivam Rao   21     CSAIML     2   7.8        81.0
# Female     CS100     Avni Nair   19     CSAIML     2   9.0        93.0
#
#        Internship      Club   Exam_Date  ...                   Email  \
# ...

# %%
df8 = pd.read_csv("Students.csv", header=[2])
df8
# Out:
#     CS002   Priya Patel  20  Female  CSAIML  2  7.8  90.2   No  Literary  ...  \
# 0   CS003   Rahul Verma  21    Male  CSAIML  2  6.9   NaN  Yes        AI  ...
# 1   CS004  Ananya Gupta  19  Female  CSAIML  2  9.1  92.0   No    Coding  ...
# 2   CS005  Vikram Singh  20    Male  CSAIML  2  7.5  78.5  Yes       NaN  ...
# 3   CS006    Neha Reddy  22  Female  CSAIML  2  NaN  88.0   No    Debate  ...
# 4   CS007   Akash Kumar  19    Male  CSAIML  2  8.2  91.5  Yes  Robotics  ...
# ..    ...           ...  ..     ...     ... ..  ...   ...  ...       ...  ...
# 93  CS096   Swara Reddy  21  Female  CSAIML  2  8.9  92.0   No  Literary  ...
# 94  CS097    Ayan Singh  19    Male  CSAIML  2  7.4  78.5  Yes  Robotics  ...
# 95  CS098    Riya Joshi  20  Female  CSAIML  2  8.7  90.5   No    Debate  ...
# 96  CS099    Shivam Rao  21    Male  CSAIML  2  7.8  81.0  Yes     Music  ...
# 97  CS100     Avni Nair  19  Female  CSAIML  2  9.0  93.0   No        AI  ...
#
# ...

# %%
df9 = pd.read_csv("Students.csv",dtype={"Library_Visits":"float"})
df9
# Out:
#    StudentID          Name  Age  Gender Department  Year  CGPA  Attendance  \
# 0      CS001  Arjun Sharma   19    Male     CSAIML     2   8.5        85.5
# 1      CS002   Priya Patel   20  Female     CSAIML     2   7.8        90.2
# 2      CS003   Rahul Verma   21    Male     CSAIML     2   6.9         NaN
# 3      CS004  Ananya Gupta   19  Female     CSAIML     2   9.1        92.0
# 4      CS005  Vikram Singh   20    Male     CSAIML     2   7.5        78.5
# ..       ...           ...  ...     ...        ...   ...   ...         ...
# 95     CS096   Swara Reddy   21  Female     CSAIML     2   8.9        92.0
# 96     CS097    Ayan Singh   19    Male     CSAIML     2   7.4        78.5
# 97     CS098    Riya Joshi   20  Female     CSAIML     2   8.7        90.5
# 98     CS099    Shivam Rao   21    Male     CSAIML     2   7.8        81.0
# 99     CS100     Avni Nair   19  Female     CSAIML     2   9.0        93.0
#
# ...
